# %%
#-----install and import APIs
# !pip install wikipedia
import wikipedia
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-cp36-none-any.whl size=11686 sha256=70c92f76fc0839cd946d40f830499e6aaddbcc5d3f386a8f7d42e6b4859cb449
#   Stored in directory: /root/.cache/pip/wheels/87/2a/18/4e471fd96d12114d16fe4a446d00c3b38fb9efcb744bd31f4a
# Successfully built wikipedia
# ...
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#-----  make a list of topics for first layer
wikipedia.set_lang("en")
with open("/content/drive/My Drive/Colab Notebooks/SE-Req/Data/topics/social science.txt", 'w' , encoding='utf-8') as f:
        topics=wikipedia.search('social science', results=500, suggestion=True)
        for j in topics[0]:
            f.writelines(str(j)+"\n")
            print(j)

# %%
#-------create a list of topics for every category in first layer for second layer of crowling
wikipedia.set_lang("en")
#-----open first layer list
O_doc = open("/content/drive/My Drive/Colab Notebooks/SE-Req/Data/topics/social science.txt" , "r", encoding='utf-8')    
Lines_doc =O_doc.readlines()
O_doc.close()
#------create second layer list
with open("/content/drive/My Drive/Colab Notebooks/SE-Req/Data/topics/social science_sub.txt", 'w' , encoding='utf-8') as f:
  for i in Lines_doc:
   # print(i)
    #  try:
        topics=wikipedia.search(i , results=20, suggestion=True)
        print(topics)
       # print(1)
      #except:
      #  pass
        topicList=topics[0]
        #topicList
        for j in topicList:
            f.writelines(str(j)+"\n")
        #print(i)

# %%
 #-------- crowler: get a list of topics, crowl pages for them  and save page's content.
#---connect to colab.
#from google.colab import drive
#drive.mount('/content/drive')
#------set language
wikipedia.set_lang("en")
#-----get a list of topics
O_doc = open("/content/drive/My Drive/Colab Notebooks/SE-Req/Data/topics/art_sub.txt" , "r", encoding='utf-8')    
Lines_doc =O_doc.readlines()
O_doc.close()
counter=0
#global flag
#flag=1
#global limit1,limit2
#limit1=0
#limit2=0
#-------save content of each list
for topic in Lines_doc:
      counter=counter + 1
#    if counter >=9100:       #----this if helps to continue from counter number when we have lost the session(some error happened). crowl pages from counter to end. or when you want to stop crowling and start the remain pages latter.
      try:
        p=wikipedia.page(title=topic, pageid=None, auto_suggest=True, redirect=True, preload=False)
        with open("/content/drive/My Drive/Colab Notebooks/SE-Req/Data/pagesContent/At/"+str(counter)+".txt", 'w' , encoding='utf-8') as f:
            f.writelines(p.content)
        print(str(counter))
      except:
        pass
   
#    try:
#        if flag==1:
#            crowler1()
#           print(limit1)
#            print(flag)
#        if flag==2:
#            crowler2()
#            print(limit2)
#            print(flag)
#    except:
#        pass
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 9100
# 9101
# 9102
# 9103
# 9104
# 9105
# 9106
# 9107
# 9108
# 9109
# 9110
# 9111
# 9112
# 9113
# 9114
# 9115
# 9116
# 9117
# 9118
# 9119
# 9120
# 9121
# 9122
# 9123
# 9124
# 9125
# 9126
# 9127
# 9128
# 9129
# 9130
# 9131
# /usr/local/lib/python3.6/dist-packages/wikipedia/wikipedia.py:389: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /usr/local/lib/python3.6/dist-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# ...

# %% [markdown]
# following codes are extra and are not requaired.

# %%
def crowler1():
    global flag
    global limit1
    if limit1==5:
        limit1=0
        flag=2
        p=wikipedia.page(title=topic, pageid=None, auto_suggest=True, redirect=True, preload=False)
        with open("DATA/computer_science/"+str(counter)+".txt", 'w' , encoding='utf-8') as f:
            f.writelines(p.content)
        print(str(counter)+"  ..1")
        return
    
    limit1=limit1+1

    p=wikipedia.page(title=topic, pageid=None, auto_suggest=True, redirect=True, preload=False)
    with open("DATA/computer_science/"+str(counter)+".txt", 'w' , encoding='utf-8') as f:
        f.writelines(p.content)
    print(str(counter)+"  ..1")

# %%
def crowler2():
    global flag
    global limit2
    if limit2==5:
        limit2=0
        flag=1
        p=wikipedia.page(title=topic, pageid=None, auto_suggest=True, redirect=True, preload=False)
        with open("DATA/computer_science/"+str(counter)+".txt", 'w' , encoding='utf-8') as f:
            f.writelines(p.content)
        print(str(counter)+"  ..2")

        return
            
    limit2=limit2+1
      
    p=wikipedia.page(title=topic, pageid=None, auto_suggest=True, redirect=True, preload=False)
    with open("DATA/computer_science/"+str(counter)+".txt", 'w' , encoding='utf-8') as f:
        f.writelines(p.content)
    print(str(counter)+"  ..2")

# %%
from random import random

import wikipedia

wikipedia.set_lang("en")

O_doc = open("DATA/topics.txt" , "r", encoding='utf-8')    
Lines_doc =O_doc.readlines()
O_doc.close()
for topic in Lines_doc:
#def random_page():
#   random = wikipedia.random(1)

   try:
       result = wikipedia.page(topic)
       print("category : " + str(result.categories))
#       if result.categories == "computer_science" :
#           print(result.summary)
   except wikipedia.exceptions.DisambiguationError as e:
       result = random_page()
   return result

for i in range(1,200):
    with open("DATA/" + str(i) + ".txt", 'w') as f:
        while (True):
            newpage = random_page()
            print("Fetching new article" + newpage.title)
           # if (len(newpage.content) > 1200):
            f.write(newpage.content)
            print(newpage.content)
            break

# %%
p=wikipedia.page(title="Pool", pageid=None, auto_suggest=True, redirect=True, preload=False)
p.content
